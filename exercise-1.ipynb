# %% [markdown]
# <a href="https://colab.research.google.com/github/moonx008/Ruumeen/blob/main/exercise-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 1.2
print(a, b)
print(a+b, a-b, a*b, a/b)
# Out:
# 10 1.2
# 11.2 8.8 12.0 8.333333333333334
